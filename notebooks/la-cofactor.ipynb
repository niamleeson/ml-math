# %% [markdown]
# # Cofactor expansion
#
# _Linear Algebra (deep dive)_
#
# **Compute any determinant by breaking it into smaller ones — the recursive recipe.**
#
# Cofactor expansion (also called Laplace expansion) computes a determinant of any size by reducing it to smaller determinants.
#
#      Pick any one row or column. Walk along it: each entry contributes (its value) × (a sign) × (the determinant of the smaller matrix you get by crossing out that entry's row and column). Add them up.
#
# ---
#
# This notebook is a practice scaffold for the **Cofactor expansion** lesson. Run the cells, then tackle the practice problems at the bottom. _Save a copy to your Drive (File → Save a copy in Drive) to edit and keep your work._

# %%
# Setup — numpy / pandas / scikit-learn / matplotlib ship with Colab.
import numpy as np, matplotlib.pyplot as plt

# %% [markdown]
# ## Reference implementation — NumPy

# %%
import numpy as np

def det_cofactor(A):
    A = np.asarray(A, dtype=float)
    n = A.shape[0]
    if n == 1:
        return A[0, 0]
    total = 0.0
    for j in range(n):                         # expand along the first row
        minor = np.delete(np.delete(A, 0, axis=0), j, axis=1)
        total += ((-1) ** j) * A[0, j] * det_cofactor(minor)   # sign * entry * minor
    return total

A = np.array([[2, 0, 1],
              [3, 1, 2],
              [1, 0, 4]], dtype=float)
print("cofactor expansion det:", det_cofactor(A))
print("numpy det:             ", round(float(np.linalg.det(A)), 6))
print("match:", np.isclose(det_cofactor(A), np.linalg.det(A)))

# %% [markdown]
# ## Visualize the data & results
#
# _How do the signed cofactor terms along the first row sum to the determinant?_

# %%
import numpy as np
import matplotlib.pyplot as plt

A = np.array([[2, 0, 1], [3, 1, 2], [1, 0, 4]], dtype=float)
terms = []
for j in range(3):                        # expand along first row
    minor = np.delete(np.delete(A, 0, 0), j, 1)
    terms.append(((-1) ** j) * A[0, j] * np.linalg.det(minor))
detA = np.linalg.det(A)                    # 7.0

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))
ax1.imshow(A, cmap='Blues')
for i in range(3):
    for j in range(3):
        ax1.text(j, i, str(int(A[i, j])), ha='center', va='center')
ax1.set_title('A with cofactor signs')
labels = ['+ 2*det4', '- 0*det10', '+ 1*det(-1)', 'det A']
vals = [round(t) for t in terms] + [round(detA)]
ax2.bar(labels, vals, color=['#4ea1ff', '#9aa7b4', '#ff7b72', '#7ee787'])
ax2.set_title('cofactor terms sum to det A')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Practice
#
# Try each one in the empty cell below it, then reveal the worked solution.

# %% [markdown]
# **Problem 1.** Compute $\det\begin{bmatrix}1&2&3\\4&5&6\\7&8&10\end{bmatrix}$ by cofactor expansion along the first row.

# %%
# Your turn:

# %% [markdown]
# <details><summary>Show worked solution</summary>
#
# - Term 1: $+\,1\cdot\det\begin{bmatrix}5&6\\8&10\end{bmatrix} = 1\cdot(50-48) = 2$. — _Sign $(-1)^{1+1}=+$; minor deletes row 1 and column 1._
# - Term 2: $-\,2\cdot\det\begin{bmatrix}4&6\\7&10\end{bmatrix} = -2\cdot(40-42) = +4$. — _Sign $(-1)^{1+2}=-$; minor deletes row 1, column 2._
# - Term 3: $+\,3\cdot\det\begin{bmatrix}4&5\\7&8\end{bmatrix} = 3\cdot(32-35) = -9$. — _Sign $(-1)^{1+3}=+$._
# - Sum: $2 + 4 - 9 = -3$. — _Add the three signed terms to get the determinant._
#
# **Answer:** $\det = -3$.
#
# </details>

# %% [markdown]
# **Problem 2.** A $4\times 4$ matrix has a column that is all zeros except a single $5$ in row 2. Which line should you expand along, and why?

# %%
# Your turn:

# %% [markdown]
# <details><summary>Show worked solution</summary>
#
# - Expand along that column. — _Every zero entry contributes a zero term, so only the $5$ entry survives._
# - The determinant reduces to $\pm\,5$ times one $3\times 3$ minor. — _One term instead of four — cofactor expansion rewards rows/columns full of zeros._
#
# **Answer:** Expand along the sparse column: $\det = (-1)^{2+j}\cdot 5\cdot M_{2j}$, a single $3\times3$ determinant.
#
# </details>

# %% [markdown]
# **Problem 3.** Show that cofactor expansion of $\begin{bmatrix}a&b\\c&d\end{bmatrix}$ along the first row gives the familiar $ad-bc$.

# %%
# Your turn:

# %% [markdown]
# <details><summary>Show worked solution</summary>
#
# - Entry $a$, sign $+$: minor is the $1\times1$ matrix $[d]$, determinant $d$. Term $= +a\cdot d$. — _Delete row 1, col 1, leaving $d$._
# - Entry $b$, sign $-$: minor is $[c]$, determinant $c$. Term $= -b\cdot c$. — _Sign $(-1)^{1+2}=-$; delete row 1, col 2, leaving $c$._
# - Sum: $ad - bc$. — _The $2\times2$ rule is just cofactor expansion in the base case._
#
# **Answer:** $ad - bc$ — the $2\times2$ formula is the smallest cofactor expansion.
#
# </details>
