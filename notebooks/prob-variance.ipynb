# %% [markdown]
# # Variance & standard deviation
#
# _Probability & Statistics_
#
# **The mean tells you the center. Variance tells you the spread.**
#
# Two things can have the same average but feel totally different.
#
#      One is steady; the other swings wildly. The variance measures that swing.
#
# ---
#
# This notebook is a practice scaffold for the **Variance & standard deviation** lesson. Run the cells, then tackle the practice problems at the bottom. _Save a copy to your Drive (File → Save a copy in Drive) to edit and keep your work._

# %%
# Setup — numpy / pandas / scikit-learn / matplotlib ship with Colab.
import numpy as np, matplotlib.pyplot as plt

# %% [markdown]
# ## Reference implementation — NumPy + SciPy

# %%
import numpy as np
from scipy.stats import randint

x = np.arange(1, 7)
p = np.full(6, 1 / 6)
mu = np.sum(x * p)
var = np.sum((x - mu) ** 2 * p)     # E[(X-mu)^2]
print("Var(X) formula =", round(var, 4), " std =", round(var ** 0.5, 4))

# scipy gives the same for discrete uniform on 1..6.
d = randint(1, 7)
print("scipy  Var =", round(d.var(), 4), " std =", round(d.std(), 4))

# Verify from samples (ddof=0 = population variance).
rng = np.random.default_rng(0)
s = rng.integers(1, 7, size=1_000_000)
print("sample Var =", round(s.var(), 4), " std =", round(s.std(), 4))

# %% [markdown]
# ## Visualize the data & results
#
# _How far do die faces sit from the mean, and what is the variance?_

# %%
import numpy as np
import matplotlib.pyplot as plt

# Squared deviations of each die face from the mean 3.5.
x = np.arange(1, 7)
p = np.full(6, 1 / 6)
mu = np.sum(x * p)
sq_dev = (x - mu) ** 2

plt.bar([str(v) for v in x], sq_dev, color='#c89bff')
plt.title('Squared deviations (x-3.5)^2 per face; Var(X) is their average')
plt.xlabel('face')
plt.ylabel('(x - mu)^2')
plt.show()
